# %% [markdown]
# # Kelompok V
# Anggota Kelompok V :
#
# 1. Putu Agus Arya Suta (2208541012)
# 2. I Dewa Ayu Pradnya Pratiwi T. (2208541013)
# 3. Ni Putu Dina Agustina (2208541043)
#
# Pada project kali ini, kami berkesempatan untuk mengeksplorasi data terkait dengan hujan.

# %% [markdown]
# # Menampilkan Data Hujan

# %%
#pada bagian pertama eksplorasi data, terlebih dahulu kita akan menampilkan data hujan tersebut
#pada bagian ini sebelum kita menampilkan data yang akan kita panggil, kita akan mengimport pandas yang bertujuan untuk memanngil data pandas
#serta kita juga akan mengimpor warnings
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

#pd.options.display.max_rows ini untuk bertujuan untuk mengatur berapa banyak maksimal baris yang ingin ditampilkan pada notebook
#disini kami mengatur tampilan maksimal untuk baris sebanyak 100 saja
pd.set_option("display.max_columns", 100)

# %%
data_hujan = pd.read_csv("https://raw.githubusercontent.com/imdwipayana/DATA/main/Dataset%20Final%20Project%202023/Hujan/hujan.csv") 
data_hujan
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            NaN           W           44.0          W        WNW
# ...

# %%
data_hujan.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
data_hujan.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
data_hujan = data_hujan.drop(['Date', 'Location', 'WindGustDir', 'WindDir9am','WindDir3pm'], axis=1)
data_hujan
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6          NaN       NaN           44.0
# 1           7.4     25.1       0.0          NaN       NaN           44.0
# 2          12.9     25.7       0.0          NaN       NaN           46.0
# 3           9.2     28.0       0.0          NaN       NaN           24.0
# 4          17.5     32.3       1.0          NaN       NaN           41.0
# ...         ...      ...       ...          ...       ...            ...
# 145455      2.8     23.4       0.0          NaN       NaN           31.0
# 145456      3.6     25.3       0.0          NaN       NaN           22.0
# 145457      5.4     26.9       0.0          NaN       NaN           37.0
# 145458      7.8     27.0       0.0          NaN       NaN           28.0
# 145459     14.9      NaN       0.0          NaN       NaN            NaN
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
data_hujan.isnull().sum()
# Out:
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustSpeed    10263
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# # MENGECEK OUTLIER

# %%
#mengecek outlier 
import numpy as np
data_hujan.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'MinTemp'
import seaborn as sns
sns.boxplot(data_hujan['MinTemp'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'MaxTemp'
import seaborn as sns
sns.boxplot(data_hujan['MaxTemp'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Rainfall'
import seaborn as sns
sns.boxplot(data_hujan['Rainfall'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Evporation'
import seaborn as sns
sns.boxplot(data_hujan['Evaporation'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Sunshine'
import seaborn as sns
sns.boxplot(data_hujan['Sunshine'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'WindGustSpeed'
import seaborn as sns
sns.boxplot(data_hujan['WindGustSpeed'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'WindSpeed9am'
import seaborn as sns
sns.boxplot(data_hujan['WindSpeed9am'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'WindSpeed3pm'
import seaborn as sns
sns.boxplot(data_hujan['WindSpeed3pm'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Humidity9am'
import seaborn as sns
sns.boxplot(data_hujan['Humidity9am'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Humidity3pm'
import seaborn as sns
sns.boxplot(data_hujan['Humidity3pm'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Pressure9am'
import seaborn as sns
sns.boxplot(data_hujan['Pressure9am'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Pressure3pm'
import seaborn as sns
sns.boxplot(data_hujan['Pressure3pm'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Cloud9am'
import seaborn as sns
sns.boxplot(data_hujan['Cloud9am'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Cloud3pm'
import seaborn as sns
sns.boxplot(data_hujan['Cloud3pm'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Temp9am'
import seaborn as sns
sns.boxplot(data_hujan['Temp9am'])
# Out:
# <Axes: >

# %%
#Menggunakan Boxplot untuk mengetahui posisi Outlier pada 'Temp3pm'
import seaborn as sns
sns.boxplot(data_hujan['Temp3pm'])
# Out:
# <Axes: >

# %% [markdown]
# # MENGISI DATA KOSONG

# %%
#pada saat mengecek outlier kolom 'Sunshine','Humidity3pm', 'Cloud9am', 'Cloud3pm' tidak ada outliernya jadi kita mengisi data
#yang kosong dengan mean
data_hujan[['Sunshine','Humidity3pm', 'Cloud9am', 'Cloud3pm' ]] = data_hujan[['Sunshine','Humidity3pm', 'Cloud9am', 'Cloud3pm' ]].fillna(data_hujan[['Sunshine','Humidity3pm', 'Cloud9am', 'Cloud3pm' ]].mean())

# %%
data_hujan
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6          NaN  7.611178           44.0
# 1           7.4     25.1       0.0          NaN  7.611178           44.0
# 2          12.9     25.7       0.0          NaN  7.611178           46.0
# 3           9.2     28.0       0.0          NaN  7.611178           24.0
# 4          17.5     32.3       1.0          NaN  7.611178           41.0
# ...         ...      ...       ...          ...       ...            ...
# 145455      2.8     23.4       0.0          NaN  7.611178           31.0
# 145456      3.6     25.3       0.0          NaN  7.611178           22.0
# 145457      5.4     26.9       0.0          NaN  7.611178           37.0
# 145458      7.8     27.0       0.0          NaN  7.611178           28.0
# 145459     14.9      NaN       0.0          NaN  7.611178            NaN
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
data_hujan.isnull().sum()
# Out:
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine             0
# WindGustSpeed    10263
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm          0
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am             0
# Cloud3pm             0
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
#kolom yang berisi outlier, kita isi datanya dengan menggunakan median
data_hujan[['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'WindGustSpeed', 'WindSpeed9am', 
            'WindSpeed3pm', 'Humidity9am','Pressure9am', 'Pressure3pm', 'Temp9am', 
            'Temp3pm']] = data_hujan[['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',  
                                      'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 
                                      'Pressure9am', 'Pressure3pm', 
                                      'Temp9am', 'Temp3pm']].fillna(data_hujan[['MinTemp', 'MaxTemp', 'Rainfall', 
                                                                                            'Evaporation', 'WindGustSpeed', 
                                                                                            'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',  
                                                                                            'Pressure9am', 'Pressure3pm','Temp9am', 'Temp3pm']].median())

# %%
data_hujan
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6          4.8  7.611178           44.0
# 1           7.4     25.1       0.0          4.8  7.611178           44.0
# 2          12.9     25.7       0.0          4.8  7.611178           46.0
# 3           9.2     28.0       0.0          4.8  7.611178           24.0
# 4          17.5     32.3       1.0          4.8  7.611178           41.0
# ...         ...      ...       ...          ...       ...            ...
# 145455      2.8     23.4       0.0          4.8  7.611178           31.0
# 145456      3.6     25.3       0.0          4.8  7.611178           22.0
# 145457      5.4     26.9       0.0          4.8  7.611178           37.0
# 145458      7.8     27.0       0.0          4.8  7.611178           28.0
# 145459     14.9     22.6       0.0          4.8  7.611178           39.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
data_hujan.isnull().sum()
# Out:
# MinTemp             0
# MaxTemp             0
# Rainfall            0
# Evaporation         0
# Sunshine            0
# WindGustSpeed       0
# WindSpeed9am        0
# WindSpeed3pm        0
# Humidity9am         0
# Humidity3pm         0
# Pressure9am         0
# Pressure3pm         0
# Cloud9am            0
# Cloud3pm            0
# Temp9am             0
# Temp3pm             0
# RainToday        3261
# RainTomorrow     3267
# dtype: int64

# %%
data_hujan = data_hujan.dropna()

# %%
data_hujan.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
data_hujan['RainTomorrow'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data_hujan['RainTomorrow'] = data_hujan['RainTomorrow'].map({'No':0, 'Yes':1})

# %%
data_hujan = pd.get_dummies(data_hujan)

# %%
data_hujan
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6          4.8  7.611178           44.0
# 1           7.4     25.1       0.0          4.8  7.611178           44.0
# 2          12.9     25.7       0.0          4.8  7.611178           46.0
# 3           9.2     28.0       0.0          4.8  7.611178           24.0
# 4          17.5     32.3       1.0          4.8  7.611178           41.0
# ...         ...      ...       ...          ...       ...            ...
# 145454      3.5     21.8       0.0          4.8  7.611178           31.0
# 145455      2.8     23.4       0.0          4.8  7.611178           31.0
# 145456      3.6     25.3       0.0          4.8  7.611178           22.0
# 145457      5.4     26.9       0.0          4.8  7.611178           37.0
# 145458      7.8     27.0       0.0          4.8  7.611178           28.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
data_hujan.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustSpeed    float64
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainTomorrow       int64
# RainToday_No       uint8
# RainToday_Yes      uint8
# dtype: object

# %% [markdown]
# # KESEIMBANGAN DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_columns", 100)
pd.set_option('display.max_rows',100)

# %%
X = data_hujan.drop(['RainToday_Yes'],axis=1)
y = data_hujan['RainToday_Yes']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112629 entries, 123818 to 11394
# Data columns (total 18 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   MinTemp        112629 non-null  float64
#  1   MaxTemp        112629 non-null  float64
#  2   Rainfall       112629 non-null  float64
#  3   Evaporation    112629 non-null  float64
#  4   Sunshine       112629 non-null  float64
#  5   WindGustSpeed  112629 non-null  float64
#  6   WindSpeed9am   112629 non-null  float64
#  7   WindSpeed3pm   112629 non-null  float64
#  8   Humidity9am    112629 non-null  float64
#  9   Humidity3pm    112629 non-null  float64
#  10  Pressure9am    112629 non-null  float64
#  11  Pressure3pm    112629 non-null  float64
#  12  Cloud9am       112629 non-null  float64
#  13  Cloud3pm       112629 non-null  float64
#  14  Temp9am        112629 non-null  float64
#  15  Temp3pm        112629 non-null  float64
# ...

# %%
y_train.hist()
# Out:
# <Axes: >

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
X_os,y_os = RandomOverSampler().fit_resample(X_train,y_train)

# %%
y_os.hist()
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_lr = LogisticRegression()

# %%
model_lr.fit(X_os,y_os)
# Out:
# LogisticRegression()

# %%
model_lr.score(X_test,y_test)
# Out:
# 0.9933589033312025

# %%
# Dengan tanpa oversampling
model_lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model_lr.score(X_test,y_test)
# Out:
# 0.9978336529583067

# %% [markdown]
# # KORELASI

# %%
#kembali dicetak data hujan yang telah dimiliki sebelumnya
data_hujan
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6          4.8  7.611178           44.0
# 1           7.4     25.1       0.0          4.8  7.611178           44.0
# 2          12.9     25.7       0.0          4.8  7.611178           46.0
# 3           9.2     28.0       0.0          4.8  7.611178           24.0
# 4          17.5     32.3       1.0          4.8  7.611178           41.0
# ...         ...      ...       ...          ...       ...            ...
# 145454      3.5     21.8       0.0          4.8  7.611178           31.0
# 145455      2.8     23.4       0.0          4.8  7.611178           31.0
# 145456      3.6     25.3       0.0          4.8  7.611178           22.0
# 145457      5.4     26.9       0.0          4.8  7.611178           37.0
# 145458      7.8     27.0       0.0          4.8  7.611178           28.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
data_hujan.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.734409  0.103747     0.368703  0.052590
# MaxTemp        0.734409  1.000000 -0.074614     0.452916  0.333012
# Rainfall       0.103747 -0.074614  1.000000    -0.042390 -0.173455
# Evaporation    0.368703  0.452916 -0.042390     1.000000  0.288023
# Sunshine       0.052590  0.333012 -0.173455     0.288023  1.000000
# WindGustSpeed  0.173484  0.067769  0.127689     0.150709 -0.021317
# WindSpeed9am   0.175070  0.014516  0.086334     0.150239  0.006909
# WindSpeed3pm   0.174408  0.050721  0.057108     0.101613  0.040206
# Humidity9am   -0.233159 -0.501752  0.222236    -0.389216 -0.353814
# Humidity3pm    0.005627 -0.500654  0.250676    -0.298624 -0.448559
# Pressure9am   -0.424662 -0.308974 -0.160405    -0.215277  0.030962
# Pressure3pm   -0.434575 -0.397604 -0.120955    -0.235494 -0.015473
# Cloud9am       0.060861 -0.228180  0.171923    -0.162641 -0.539564
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
fig, ax = plt.subplots(figsize=(9,9))
sns.heatmap(data_hujan.corr(),ax=ax,annot=True)
# Out:
# <Axes: >

# %%
data_hujan1 = data_hujan[['MaxTemp','MinTemp','RainToday_No', 'RainToday_Yes']]
data_hujan1.corr()
# Out:
#                 MaxTemp   MinTemp  RainToday_No  RainToday_Yes
# MaxTemp        1.000000  0.734409      0.228636      -0.228636
# MinTemp        0.734409  1.000000     -0.056099       0.056099
# RainToday_No   0.228636 -0.056099      1.000000      -1.000000
# RainToday_Yes -0.228636  0.056099     -1.000000       1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
fig, ax = plt.subplots(figsize=(9,9))
sns.heatmap(data_hujan1.corr(),ax=ax,annot=True)
# Out:
# <Axes: >

# %%
data_hujan2 = data_hujan[['WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm','RainToday_No', 'RainToday_Yes']]
data_hujan2.corr()
# Out:
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm  RainToday_No  \
# WindGustSpeed       1.000000      0.579563      0.659731     -0.149359
# WindSpeed9am        0.579563      1.000000      0.513319     -0.101880
# WindSpeed3pm        0.659731      0.513319      1.000000     -0.079333
# RainToday_No       -0.149359     -0.101880     -0.079333      1.000000
# RainToday_Yes       0.149359      0.101880      0.079333     -1.000000
#
#                RainToday_Yes
# WindGustSpeed       0.149359
# WindSpeed9am        0.101880
# WindSpeed3pm        0.079333
# RainToday_No       -1.000000
# RainToday_Yes       1.000000

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(9,9))
sns.heatmap(data_hujan2.corr(),ax=ax,annot=True)
# Out:
# <Axes: >

# %%
data_hujan3 = data_hujan[['Humidity9am', 'Humidity3pm', 'RainToday_No', 'RainToday_Yes']]
data_hujan3.corr()
# Out:
#                Humidity9am  Humidity3pm  RainToday_No  RainToday_Yes
# Humidity9am       1.000000     0.661058     -0.351126       0.351126
# Humidity3pm       0.661058     1.000000     -0.373514       0.373514
# RainToday_No     -0.351126    -0.373514      1.000000      -1.000000
# RainToday_Yes     0.351126     0.373514     -1.000000       1.000000

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(9,9))
sns.heatmap(data_hujan3.corr(),ax=ax,annot=True)
# Out:
# <Axes: >

# %%
data_hujan4 = data_hujan[['Pressure9am', 'Pressure3pm', 'RainToday_No', 'RainToday_Yes']]
data_hujan4.corr()
# Out:
#                Pressure9am  Pressure3pm  RainToday_No  RainToday_Yes
# Pressure9am       1.000000     0.960051      0.180351      -0.180351
# Pressure3pm       0.960051     1.000000      0.100997      -0.100997
# RainToday_No      0.180351     0.100997      1.000000      -1.000000
# RainToday_Yes    -0.180351    -0.100997     -1.000000       1.000000

# %%
data_hujan5 = data_hujan[['Temp9am', 'Temp3pm', 'RainToday_No', 'RainToday_Yes']]
data_hujan5.corr()
# Out:
#                 Temp9am   Temp3pm  RainToday_No  RainToday_Yes
# Temp9am        1.000000  0.847432      0.096346      -0.096346
# Temp3pm        0.847432  1.000000      0.232598      -0.232598
# RainToday_No   0.096346  0.232598      1.000000      -1.000000
# RainToday_Yes -0.096346 -0.232598     -1.000000       1.000000

# %%
data_hujan6 = data_hujan[['MaxTemp', 'Temp3pm', 'RainToday_No', 'RainToday_Yes']]
data_hujan6.corr()
# Out:
#                 MaxTemp   Temp3pm  RainToday_No  RainToday_Yes
# MaxTemp        1.000000  0.969864      0.228636      -0.228636
# Temp3pm        0.969864  1.000000      0.232598      -0.232598
# RainToday_No   0.228636  0.232598      1.000000      -1.000000
# RainToday_Yes -0.228636 -0.232598     -1.000000       1.000000

# %%
data_hujan7 = data_hujan6 = data_hujan[['MaxTemp', 'Temp3pm', "RainToday_No", 'RainToday_Yes']]
data_hujan7.corr()
# Out:
#                 MaxTemp   Temp3pm  RainToday_No  RainToday_Yes
# MaxTemp        1.000000  0.969864      0.228636      -0.228636
# Temp3pm        0.969864  1.000000      0.232598      -0.232598
# RainToday_No   0.228636  0.232598      1.000000      -1.000000
# RainToday_Yes -0.228636 -0.232598     -1.000000       1.000000

# %% [markdown]
# # Menghitung korelasi antara kolom "Max Temperature" dan "Temp 3 pm "

# %%
data_hujan.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  140787.000000  140787.000000  140787.000000  140787.000000
# mean       12.184209      23.233735       2.349974       5.187367
# std         6.393235       7.106800       8.465173       3.196637
# min        -8.500000      -4.800000       0.000000       0.000000
# 25%         7.600000      17.900000       0.000000       4.000000
# 50%        12.000000      22.600000       0.000000       4.800000
# 75%        16.800000      28.200000       0.800000       5.400000
# max        33.900000      48.100000     371.000000     145.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  140787.000000  140787.000000  140787.000000  140787.000000
# mean        7.621352      39.907754      13.983074      18.637772
# std         2.741407      13.133963       8.853265       8.718790
# min         0.000000       6.000000       0.000000       0.000000
# ...

# %%
import pandas as pd #mengimpor library pandas
import seaborn as sns #mengimpor library seaborn untuk grafik statistik
import matplotlib.pyplot as plt #mengimpor matplotlib untuk menciptakan visual data yang lebih menarik

# %%
# Menentukan apakah ada hujan berdasarkan Max Temperature dan Kecepatan Angin
threshold_temp3pm = 21.68  # Nilai ambang batas temperatur maksimum untuk menentukan ada hujan atau tidak 
threshold_maxtemp = 23.24  # Nilai ambang batas kecepatan angin untuk menentukan ada hujan atau tidak
#nilai ambang 30 dan 20 dapat dilihat berdasarkan grafik batang dari distribusi Max Temperature dan Kecepatan Angin 
#dengan Hujan dan Tidak Hujan serta berdasarkan grafik batang dari distribusi kecepatan angin dengan hujan dan tidak hujan

# %%
#akan dibentuk diagram batang korelasi data hujan dengan indikator variabel sebagai berikut.
data_hujan['Hujan'] = ((data_hujan['MaxTemp'] > threshold_temp3pm) & (data_hujan['Temp3pm'] > threshold_maxtemp))
#selanjutnya dengan menggunakan logika matematika, akan dibentuk 2 diagram berbeda yakni bernilai true dan false
data_hujan['Hujan'] = data_hujan['Hujan'].map({True: 'Ya', False: 'Tidak'})

# %%
def predict_rain(suhu, temp3pm) :
    # Menentukan apakah ada hujan berdasarkan Max Temperature dan Kecepatan Angin
    threshold_maxtemp = 23.24 # Nilai ambang batas temperatur maksimum untuk menentukan ada hujan atau tidak
    threshold_temp3pm = 21.68  # Nilai ambang batas kecepatan angin untuk menentukan ada hujan atau tidak

    if suhu < threshold_maxtemp and temp3pm < threshold_temp3pm:
        return "Hujan"
    else:
        return "Tidak Hujan"

# Input suhu dan kecepatan angin dari pengguna
input_maxtemp = float(input("Masukkan suhu maksimal : "))
input_temp3pm = float(input("Masukkan temperatur pukul 15.00 : "))

# Memprediksi apakah hujan atau tidak berdasarkan suhu dan kecepatan angin yang diinput
hasil_prediksi = predict_rain(input_maxtemp, input_temp3pm)
print("Prediksi: ", hasil_prediksi)
# Out:
# Masukkan suhu maksimal : 15
# Masukkan temperatur pukul 15.00 : 20
# Prediksi:  Hujan
